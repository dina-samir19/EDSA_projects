# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv("auto.csv")

# %%
data.head(20)
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0   18.0          8         307.0        130    3504          12.0    70
# 1   15.0          8         350.0        165    3693          11.5    70
# 2   18.0          8         318.0        150    3436          11.0    70
# 3   16.0          8         304.0        150    3433          12.0    70
# 4   17.0          8         302.0        140    3449          10.5    70
# 5   15.0          8         429.0        198    4341          10.0    70
# 6   14.0          8         454.0        220    4354           9.0    70
# 7   14.0          8         440.0        215    4312           8.5    70
# 8   14.0          8         455.0        225    4425          10.0    70
# 9   15.0          8         390.0        190    3850           8.5    70
# 10  15.0          8         383.0        170    3563          10.0    70
# 11  14.0          8         340.0        160    3609           8.0    70
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 397 entries, 0 to 396
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           397 non-null    float64
#  1   cylinders     397 non-null    int64
#  2   displacement  397 non-null    float64
#  3   horsepower    397 non-null    object
#  4   weight        397 non-null    int64
#  5   acceleration  397 non-null    float64
#  6   year          397 non-null    int64
#  7   origin        397 non-null    int64
#  8   name          397 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.0+ KB

# %%
data.describe().T
# Out:
#               count         mean         std     min     25%     50%     75%  \
# mpg           397.0    23.515869    7.825804     9.0    17.5    23.0    29.0
# cylinders     397.0     5.458438    1.701577     3.0     4.0     4.0     8.0
# displacement  397.0   193.532746  104.379583    68.0   104.0   146.0   262.0
# weight        397.0  2970.261965  847.904119  1613.0  2223.0  2800.0  3609.0
# acceleration  397.0    15.555668    2.749995     8.0    13.8    15.5    17.1
# year          397.0    75.994962    3.690005    70.0    73.0    76.0    79.0
# origin        397.0     1.574307    0.802549     1.0     1.0     1.0     2.0
#
#                  max
# mpg             46.6
# cylinders        8.0
# displacement   455.0
# weight        5140.0
# acceleration    24.8
# year            82.0
# origin           3.0

# %%
plt.hist(data.mpg, bins=50)

# label the axes 
plt.xlabel('mpg')
plt.ylabel('data ')
# Out:
# Text(0, 0.5, 'data ')

# %%
sns.pairplot(data)

# %%
sns.pairplot(data ,hue="mpg" )
plt.show()
# Out:
# C:\Users\Qebaa\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Qebaa\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Qebaa\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Qebaa\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Qebaa\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# ...

# %%
data.corr()
# Out:
#                    mpg  cylinders  displacement    weight  acceleration  \
# mpg           1.000000  -0.776260     -0.804443 -0.831739      0.422297
# cylinders    -0.776260   1.000000      0.950920  0.897017     -0.504061
# displacement -0.804443   0.950920      1.000000  0.933104     -0.544162
# weight       -0.831739   0.897017      0.933104  1.000000     -0.419502
# acceleration  0.422297  -0.504061     -0.544162 -0.419502      1.000000
# year          0.581469  -0.346717     -0.369804 -0.307900      0.282901
# origin        0.563698  -0.564972     -0.610664 -0.581265      0.210084
#
#                   year    origin
# mpg           0.581469  0.563698
# cylinders    -0.346717 -0.564972
# displacement -0.369804 -0.610664
# weight       -0.307900 -0.581265
# acceleration  0.282901  0.210084
# year          1.000000  0.184314
# origin        0.184314  1.000000

# %%
data.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'year', 'origin', 'name'],
#       dtype='object')

# %%
def scatter_plot(x):
    
    plt.scatter(data['mpg'], data[x])
    plt.title(x +' vs mpg') #title of the graph
    plt.xlabel('mpg') #x-axis
    plt.ylabel(x) #y-axis
    plt.show()


scatter_plot('cylinders') 
scatter_plot('displacement') 
scatter_plot('horsepower') 
scatter_plot('weight') 
scatter_plot('acceleration')
scatter_plot('year')
scatter_plot('origin')

# %%
sns.set(rc={'figure.figsize':(10,8)})
sns.heatmap(data.corr(), cmap='RdYlBu', square=True)
# Out:
# <AxesSubplot:>

# %%
data1=data.drop(['name'], axis=1)

# %%
data1
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0        130    3504          12.0    70
# 1    15.0          8         350.0        165    3693          11.5    70
# 2    18.0          8         318.0        150    3436          11.0    70
# 3    16.0          8         304.0        150    3433          12.0    70
# 4    17.0          8         302.0        140    3449          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 392  27.0          4         140.0         86    2790          15.6    82
# 393  44.0          4          97.0         52    2130          24.6    82
# 394  32.0          4         135.0         84    2295          11.6    82
# 395  28.0          4         120.0         79    2625          18.6    82
# 396  31.0          4         119.0         82    2720          19.4    82
#
#      origin
# 0         1
# 1         1
# 2         1
# 3         1
# ...

# %%
data1['mpg'].value_counts()
# Out:
# 13.0    20
# 14.0    19
# 18.0    17
# 15.0    16
# 26.0    14
#         ..
# 26.5     1
# 19.1     1
# 33.8     1
# 28.1     1
# 31.8     1
# Name: mpg, Length: 129, dtype: int64

# %%
data1['cylinders'].value_counts()
# Out:
# 4    203
# 8    103
# 6     84
# 3      4
# 5      3
# Name: cylinders, dtype: int64

# %%
data1['displacement'].value_counts()
# Out:
# 97.0     21
# 350.0    18
# 98.0     18
# 318.0    17
# 250.0    17
#          ..
# 83.0      1
# 181.0     1
# 81.0      1
# 96.0      1
# 144.0     1
# Name: displacement, Length: 82, dtype: int64

# %%
data1['horsepower'].value_counts()
# Out:
# 150    22
# 90     20
# 88     19
# 110    18
# 100    17
#        ..
# 142     1
# 230     1
# 64      1
# 152     1
# 200     1
# Name: horsepower, Length: 94, dtype: int64

# %%
data1['weight'].value_counts()
# Out:
# 1985    4
# 2130    4
# 2155    3
# 2720    3
# 2265    3
#        ..
# 2223    1
# 2735    1
# 3245    1
# 2219    1
# 2145    1
# Name: weight, Length: 350, dtype: int64

# %%
data1['acceleration'].value_counts()
# Out:
# 14.5    23
# 15.5    21
# 14.0    16
# 16.0    16
# 13.5    15
#         ..
# 18.3     1
# 11.1     1
# 19.9     1
# 20.7     1
# 11.3     1
# Name: acceleration, Length: 95, dtype: int64

# %%
data1['year'].value_counts()
# Out:
# 73    40
# 78    36
# 76    34
# 75    30
# 82    30
# 70    29
# 79    29
# 80    29
# 81    29
# 71    28
# 72    28
# 77    28
# 74    27
# Name: year, dtype: int64

# %%
data1['origin'].value_counts()
# Out:
# 1    248
# 3     79
# 2     70
# Name: origin, dtype: int64

# %%
data1['origin'] = pd.Categorical(data1.origin)

# %%
data1
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0        130    3504          12.0    70
# 1    15.0          8         350.0        165    3693          11.5    70
# 2    18.0          8         318.0        150    3436          11.0    70
# 3    16.0          8         304.0        150    3433          12.0    70
# 4    17.0          8         302.0        140    3449          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 392  27.0          4         140.0         86    2790          15.6    82
# 393  44.0          4          97.0         52    2130          24.6    82
# 394  32.0          4         135.0         84    2295          11.6    82
# 395  28.0          4         120.0         79    2625          18.6    82
# 396  31.0          4         119.0         82    2720          19.4    82
#
#     origin
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
# ...

# %%
data1['year'] = pd.Categorical(data1.year)

# %%
data1
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration year  \
# 0    18.0          8         307.0        130    3504          12.0   70
# 1    15.0          8         350.0        165    3693          11.5   70
# 2    18.0          8         318.0        150    3436          11.0   70
# 3    16.0          8         304.0        150    3433          12.0   70
# 4    17.0          8         302.0        140    3449          10.5   70
# ..    ...        ...           ...        ...     ...           ...  ...
# 392  27.0          4         140.0         86    2790          15.6   82
# 393  44.0          4          97.0         52    2130          24.6   82
# 394  32.0          4         135.0         84    2295          11.6   82
# 395  28.0          4         120.0         79    2625          18.6   82
# 396  31.0          4         119.0         82    2720          19.4   82
#
#      origin
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
# ...

# %%
data1.origin.astype('category')
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 392    1
# 393    2
# 394    1
# 395    1
# 396    1
# Name: origin, Length: 397, dtype: category
# Categories (3, int64): [1, 2, 3]

# %%
data.isnull().value_counts()
# Out:
# mpg    cylinders  displacement  horsepower  weight  acceleration  year   origin  name
# False  False      False         False       False   False         False  False   False    397
# dtype: int64

# %%
data1['cylinders_category'] = data1['cylinders'].astype('category')
data1['year_category'] = data1['year'].astype('category')
data1['origin_category'] = data1['origin'].astype('category')

# %%
data1
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0        130    3504          12.0    70
# 1    15.0          8         350.0        165    3693          11.5    70
# 2    18.0          8         318.0        150    3436          11.0    70
# 3    16.0          8         304.0        150    3433          12.0    70
# 4    17.0          8         302.0        140    3449          10.5    70
# ..    ...        ...           ...        ...     ...           ...   ...
# 392  27.0          4         140.0         86    2790          15.6    82
# 393  44.0          4          97.0         52    2130          24.6    82
# 394  32.0          4         135.0         84    2295          11.6    82
# 395  28.0          4         120.0         79    2625          18.6    82
# 396  31.0          4         119.0         82    2720          19.4    82
#
#      origin cylinders_category year_category origin_category
# ...

# %%
data2=data1.drop(['cylinders','year','origin'],axis=1)

# %%
data2
# Out:
#       mpg  displacement horsepower  weight  acceleration cylinders_category  \
# 0    18.0         307.0        130    3504          12.0                  8
# 1    15.0         350.0        165    3693          11.5                  8
# 2    18.0         318.0        150    3436          11.0                  8
# 3    16.0         304.0        150    3433          12.0                  8
# 4    17.0         302.0        140    3449          10.5                  8
# ..    ...           ...        ...     ...           ...                ...
# 392  27.0         140.0         86    2790          15.6                  4
# 393  44.0          97.0         52    2130          24.6                  4
# 394  32.0         135.0         84    2295          11.6                  4
# 395  28.0         120.0         79    2625          18.6                  4
# 396  31.0         119.0         82    2720          19.4                  4
#
#     year_category origin_category
# ...

# %%
print (data2.dtypes)
# Out:
# mpg                    float64
# displacement           float64
# horsepower              object
# weight                   int64
# acceleration           float64
# cylinders_category    category
# year_category         category
# origin_category       category
# dtype: object

# %%
data2.value_counts()
# Out:
# mpg   displacement  horsepower  weight  acceleration  cylinders_category  year_category  origin_category
# 9.0   304.0         193         4732    18.5          8                   70             1                  1
# 27.2  119.0         97          2300    14.7          4                   78             3                  1
# 27.0  151.0         90          2735    18.0          4                   82             1                  1
#       140.0         86          2790    15.6          4                   82             1                  1
#       112.0         88          2640    18.6          4                   82             1                  1
#                                                                                                            ..
# 18.6  225.0         110         3620    18.7          6                   78             1                  1
# ...

# %%
y= data2.mpg

# %%
y
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 392    27.0
# 393    44.0
# 394    32.0
# 395    28.0
# 396    31.0
# Name: mpg, Length: 397, dtype: float64

# %%
x=data2.drop(['mpg','horsepower'], axis=1)

# %%
x
# Out:
#      displacement  weight  acceleration cylinders_category year_category  \
# 0           307.0    3504          12.0                  8            70
# 1           350.0    3693          11.5                  8            70
# 2           318.0    3436          11.0                  8            70
# 3           304.0    3433          12.0                  8            70
# 4           302.0    3449          10.5                  8            70
# ..            ...     ...           ...                ...           ...
# 392         140.0    2790          15.6                  4            82
# 393          97.0    2130          24.6                  4            82
# 394         135.0    2295          11.6                  4            82
# 395         120.0    2625          18.6                  4            82
# 396         119.0    2720          19.4                  4            82
#
#     origin_category
# 0                 1
# 1                 1
# 2                 1
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, make_scorer
from sklearn.linear_model import Ridge
from sklearn.model_selection import cross_val_score

# %%
##Split the data
X_train, X_test, y_train, y_test =\
                train_test_split(x, y, 
                    test_size=0.20, 
                        random_state=10123)

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV

# %%
alpha_space = np.logspace(-5, 2, 25)
param_dist = {'alpha': alpha_space}

# %%
rid_reg = Ridge(fit_intercept=False)

# %%
r_reg = Ridge(fit_intercept=False)

# %%
rreg_cv = GridSearchCV(r_reg, 
                       param_grid = param_grid, 
                       cv = 5)

# %%
# Fit it to the data
rreg_cv.fit(x, y)

# Print the tuned parameters and score
print("Tuned Ridge Regression Parameter: {}".format(rreg_cv.best_params_)) 
print("Ridge Regression Best score is {}".format(rreg_cv.best_score_))
# Out:
# Tuned Ridge Regression Parameter: {'alpha': 1e-05}
# Ridge Regression Best score is 0.6171246699095894
